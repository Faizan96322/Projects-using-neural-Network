# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizan96322/Projects-using-neural-Network/blob/main/heart_disease_prediction_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import tensorflow as tf

# %%
heart_data= pd.read_csv('/content/diabetes.csv')

# %%
heart_data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
X = heart_data.iloc[:,:-1]
Y = heart_data.iloc[:,-1]
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
heart_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Building ANN

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=12, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=8, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=4, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = ann.fit(X_train,Y_train, batch_size = 32, epochs = 500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8111
# Epoch 2/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8062
# Epoch 3/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8127
# Epoch 4/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8160
# Epoch 5/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8192
# Epoch 6/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8290
# Epoch 7/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3739 - accuracy: 0.8241
# Epoch 8/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8143
# Epoch 9/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8160
# Epoch 10/500
# ...

# %%
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)

from sklearn.metrics import accuracy_score
accuracy_score(Y_test, y_pred)
# Out:
# 0.7207792207792207
